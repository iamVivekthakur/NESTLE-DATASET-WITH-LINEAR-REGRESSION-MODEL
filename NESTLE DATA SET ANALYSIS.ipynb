# %% [markdown]
# # NESTLE DATASET ANALYSIS

# %% [markdown]
# IMPORTING NECCESSARY LIBRARIES REQUIRED FOR ANALYSIS.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as st
import warnings
warnings.filterwarnings("ignore")
import math

# %% [markdown]
# # Reading the data for analysis.

# %%
df=pd.read_csv("C:\\Users\\user\\OneDrive\\Desktop\\madrid software\\MADRID CLASSES\\Data set\\nestle.csv")
df
# Out:
#                 Date  Open Price  High Price  Low Price  Close Price  \
# 0      21-April-2022    18150.00    18572.95   17772.90     18205.80
# 1      20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2      19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3      18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4      13-April-2022    18371.20    18549.30   18248.25     18343.90
# ...              ...         ...         ...        ...          ...
# 2548  6-January-2012     4114.00     4160.00    4076.00      4143.25
# 2549  5-January-2012     4118.00     4126.90    4080.00      4101.85
# 2550  4-January-2012     4100.00     4125.00    4081.40      4120.60
# 2551  3-January-2012     4061.00     4110.10    4060.10      4095.35
# 2552  2-January-2012     4139.90     4139.90    4044.00      4070.35
#
#                WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# ...

# %%
df.shape
# Out:
# (2553, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2553 entries, 0 to 2552
# Data columns (total 13 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Date                       2553 non-null   object
#  1   Open Price                 2553 non-null   float64
#  2   High Price                 2553 non-null   float64
#  3   Low Price                  2553 non-null   float64
#  4   Close Price                2553 non-null   float64
#  5   WAP                        2553 non-null   float64
#  6   No.of Shares               2553 non-null   int64
#  7   No. of Trades              2553 non-null   int64
#  8   Total Turnover (Rs.)       2553 non-null   float64
#  9   Deliverable Quantity       2551 non-null   float64
#  10  % Deli. Qty to Traded Qty  2551 non-null   float64
#  11  Spread High-Low            2553 non-null   float64
#  12  Spread Close-Open          2553 non-null   float64
# ...

# %% [markdown]
# # Finding out the null values and Filling those values.

# %%
df.isna().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         2
# % Deli. Qty to Traded Qty    2
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
df.describe(include="float").T
# Out:
#                             count          mean           std            min  \
# Open Price                 2553.0  9.338023e+03  4.940555e+03    3970.000000
# High Price                 2553.0  9.429710e+03  4.986783e+03    3995.000000
# Low Price                  2553.0  9.226856e+03  4.878971e+03    3930.000000
# Close Price                2553.0  9.324961e+03  4.932777e+03    3942.450000
# WAP                        2553.0  9.327503e+03  4.929374e+03    3936.768632
# Total Turnover (Rs.)       2553.0  4.761923e+07  8.502888e+07  172142.000000
# Deliverable Quantity       2551.0  3.264053e+03  8.652861e+03      33.000000
# % Deli. Qty to Traded Qty  2551.0  4.902446e+01  1.911974e+01       1.270000
# Spread High-Low            2553.0  2.028545e+02  1.749852e+02      17.000000
# Spread Close-Open          2553.0 -1.306263e+01  1.578492e+02   -1381.300000
#
#                                     25%           50%           75%  \
# ...

# %%
df.describe(include="int").T
# Out:
#                 count         mean           std   min     25%     50%  \
# No.of Shares   2553.0  5521.380337  10416.942384  39.0  1572.0  2618.0
# No. of Trades  2553.0  1004.099491   1137.547557   6.0   442.0   731.0
#
#                   75%       max
# No.of Shares   4981.0  154684.0
# No. of Trades  1199.0   20964.0

# %%
df["Deliverable Quantity"].value_counts()
# Out:
# 541.0     8
# 1243.0    8
# 586.0     7
# 348.0     6
# 422.0     6
#          ..
# 3077.0    1
# 264.0     1
# 669.0     1
# 314.0     1
# 5776.0    1
# Name: Deliverable Quantity, Length: 1784, dtype: int64

# %%
for column in df:
    if df[column].isnull().any():
        if df[column].dtypes==object:
            df[column].fillna(df[column].mode()[0],inplace=True)
            print('{0} -- {1}'.format(column, df[column].isnull().sum()))
        elif df[column].dtypes==float:
            df[column].fillna(math.ceil(df[column].median()),inplace=True)
            print('{0} -- {1}'.format(column, df[column].isnull().sum()))
        else:
            pass
# Out:
# Deliverable Quantity -- 0
# % Deli. Qty to Traded Qty -- 0

# %%
df.isna().sum()
# Out:
# Date                         0
# Open Price                   0
# High Price                   0
# Low Price                    0
# Close Price                  0
# WAP                          0
# No.of Shares                 0
# No. of Trades                0
# Total Turnover (Rs.)         0
# Deliverable Quantity         0
# % Deli. Qty to Traded Qty    0
# Spread High-Low              0
# Spread Close-Open            0
# dtype: int64

# %%
df.to_csv("Nestle_cleaned_dataset.csv")

# %% [markdown]
# # Since the data has cleaned now we can perform Analysis based on data.

# %%
df.head(5)
# Out:
#             Date  Open Price  High Price  Low Price  Close Price  \
# 0  21-April-2022    18150.00    18572.95   17772.90     18205.80
# 1  20-April-2022    18100.10    18415.00   18017.15     18313.70
# 2  19-April-2022    18470.05    18718.00   17845.60     17943.15
# 3  18-April-2022    18294.50    18684.50   18294.50     18549.85
# 4  13-April-2022    18371.20    18549.30   18248.25     18343.90
#
#             WAP  No.of Shares  No. of Trades  Total Turnover (Rs.)  \
# 0  18130.183442          4590           1770            83217542.0
# 1  18295.559071          6069           1321           111035748.0
# 2  18355.093320          2904            716            53303191.0
# 3  18511.224599          1496            586            27692792.0
# 4  18388.967826          1150            550            21147313.0
#
#    Deliverable Quantity  % Deli. Qty to Traded Qty  Spread High-Low  \
# 0                 950.0                      20.70           800.05
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',
#        'No.of Shares', 'No. of Trades', 'Total Turnover (Rs.)',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
df.groupby("High Price")["Low Price"].agg(["min","max"])
# Out:
#                  min       max
# High Price
# 3995.00      3932.00   3932.00
# 4024.00      3930.00   3930.00
# 4060.00      4017.00   4017.00
# 4069.95      3949.00   3949.00
# 4070.00      4011.00   4011.00
# ...              ...       ...
# 20400.00    20090.00  20090.00
# 20500.25    20243.80  20243.80
# 20517.90    19783.60  19783.60
# 20527.10    19850.00  19850.00
# 20599.95    20178.85  20178.85
#
# [2231 rows x 2 columns]

# %% [markdown]
# # Encoding

# %%
df.Date.unique()
# Out:
# array(['21-April-2022', '20-April-2022', '19-April-2022', ...,
#        '4-January-2012', '3-January-2012', '2-January-2012'], dtype=object)

# %%
df['day']=pd.to_datetime(df['Date']).dt.day
df['month']=pd.to_datetime(df['Date']).dt.month
df["year"]=pd.to_datetime(df["Date"]).dt.year
df.drop(columns=['Date'],inplace=True)

# %%
df
# Out:
#       Open Price  High Price  Low Price  Close Price           WAP  \
# 0       18150.00    18572.95   17772.90     18205.80  18130.183442
# 1       18100.10    18415.00   18017.15     18313.70  18295.559071
# 2       18470.05    18718.00   17845.60     17943.15  18355.093320
# 3       18294.50    18684.50   18294.50     18549.85  18511.224599
# 4       18371.20    18549.30   18248.25     18343.90  18388.967826
# ...          ...         ...        ...          ...           ...
# 2548     4114.00     4160.00    4076.00      4143.25   4129.486321
# 2549     4118.00     4126.90    4080.00      4101.85   4106.848723
# 2550     4100.00     4125.00    4081.40      4120.60   4105.106055
# 2551     4061.00     4110.10    4060.10      4095.35   4091.474315
# 2552     4139.90     4139.90    4044.00      4070.35   4085.640979
#
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0             4590           1770            83217542.0                 950.0
# ...

# %%
plot_number = 1
plt.figure(figsize = (15,10))
for i in ["Open Price", "High Price", "Low Price", "Close Price","WAP","No.of Shares"]:
    if plot_number<7:
        plt.subplot(3,2,plot_number)
        sns.scatterplot(x = i,y = "day",data = df)
    plot_number+=1

# %%
plot_number = 1
plt.figure(figsize = (15,10))
for i in ["Open Price", "High Price", "Low Price", "Close Price","WAP","No.of Shares"]:
    if plot_number<7:
        plt.subplot(3,2,plot_number)
        sns.scatterplot(x = i,y = "year",data = df)
    plot_number+=1

# %%
sns.distplot(df["Close Price"]);

# %%
plot_number = 1
plt.figure(figsize = (15,10))
for i in [col for col in df.columns if df[col].dtype != 'object']:
    if plot_number<7:
        plt.subplot(3,2,plot_number)
        sns.distplot(df[i]);
    plot_number+=1

# %% [markdown]
# # Finding out the correlation between the columns.

# %%
a=df.corr()

# %%
plt.figure(figsize=(12,5))
sns.heatmap(a,annot=True);

# %% [markdown]
# # Based on this heat map we can delete some columns which has corelation 1 with each other

# %%
df.drop(columns=['Open Price', 'High Price', 'Low Price', 'Close Price', 'WAP',"day","month",
                "year"], inplace=True)

# %%
df
# Out:
#       No.of Shares  No. of Trades  Total Turnover (Rs.)  Deliverable Quantity  \
# 0             4590           1770            83217542.0                 950.0
# 1             6069           1321           111035748.0                4677.0
# 2             2904            716            53303191.0                1619.0
# 3             1496            586            27692792.0                 557.0
# 4             1150            550            21147313.0                 573.0
# ...            ...            ...                   ...                   ...
# 2548          3107            444            12830314.0                2069.0
# 2549          1018            270             4180772.0                 357.0
# 2550          2857            247            11728288.0                2312.0
# 2551          5003            886            20469646.0                2817.0
# 2552          7760           1132            31704574.0                5776.0
#
# ...

# %%
import pylab

# %%
plt.figure(figsize=(7,10))
plot_num=1
for i in df.columns:
    if plot_num<7:
        plt.subplot(3,2,plot_num)
        st.probplot(df[i],dist="norm", plot=pylab)
        plt.ylabel(i)
        plot_num+=1

# %%
df.skew()
# Out:
# No.of Shares                 6.505892
# No. of Trades                7.157141
# Total Turnover (Rs.)         8.954534
# Deliverable Quantity         8.156998
# % Deli. Qty to Traded Qty    0.603466
# Spread High-Low              2.956998
# Spread Close-Open            0.397753
# dtype: float64

# %%
df.kurt()
# Out:
# No.of Shares                  58.042929
# No. of Trades                 83.982255
# Total Turnover (Rs.)         163.192224
# Deliverable Quantity          91.347682
# % Deli. Qty to Traded Qty      0.137804
# Spread High-Low               15.267866
# Spread Close-Open             13.228365
# dtype: float64

# %%
S=st.yeojohnson(df['Spread High-Low'])

# %%
S=S[0]

# %%
S= pd.Series(S)

# %%
S.skew()
# Out:
# 0.008402683581519741

# %%
S.kurt()
# Out:
# -0.45291961523610214

# %%
S=st.yeojohnson(df['Deliverable Quantity'])
S=S[0]
S= pd.Series(S)

# %%
S.skew()
# Out:
# -0.044748485412543906

# %%
S.kurt()
# Out:
# 1.0189227134015715

# %%
df.rename(columns={"Total Turnover (Rs.)": "Total_turnover"},inplace=True)

# %%
T=st.yeojohnson(df['Total_turnover'])
T=T[0]
T= pd.Series(T)

# %%
T.skew()
# Out:
# -0.01252396665862811

# %%
T.kurt()
# Out:
# 0.5141211790697975

# %%
N=st.yeojohnson(df['No. of Trades'])
N=N[0]
N= pd.Series(T)

# %%
print(N.skew())
print(N.kurt())
# Out:
# -0.01252396665862811
# 0.5141211790697975

# %%
N1=st.yeojohnson(df['No.of Shares'])
N1=N1[0]
N1= pd.Series(N1)

# %%
print(N.skew())
print(N.kurt())
# Out:
# -0.01252396665862811
# 0.5141211790697975

# %% [markdown]
# # Scalling the data

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.columns
# Out:
# Index(['No.of Shares', 'No. of Trades', 'Total_turnover',
#        'Deliverable Quantity', '% Deli. Qty to Traded Qty', 'Spread High-Low',
#        'Spread Close-Open'],
#       dtype='object')

# %%
X=df.drop(columns=["Total_turnover"])
y=df["Total_turnover"]

# %%
scaler=MinMaxScaler()
X_scaled=scaler.fit_transform(X)

# %% [markdown]
# # Data split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, Y_train, Y_test= train_test_split(X_scaled,y, test_size=0.10,random_state=235)

# %%
print(X_train.shape)
# Out:
# (2297, 6)

# %%
print(Y_train.shape)
# Out:
# (2297,)

# %% [markdown]
# # Appling Linear Regression model to check the accuracy.

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()
lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
lr.intercept_
# Out:
# -20426380.519122623

# %%
lr.coef_
# Out:
# array([ 1.90929387e+09, -3.89107182e+08, -1.02383207e+09,  5.60399705e+07,
#         2.66438867e+08, -2.64402031e+07])

# %%
Y_pred=lr.predict(X_test)

# %%
Y_pred[0:5]
# Out:
# array([4.37750689e+07, 1.31222917e+07, 1.30747713e+07, 2.41845940e+07,
#        1.46001211e+08])

# %% [markdown]
# # Performance Matrix

# %%
from sklearn.metrics import mean_absolute_error, mean_absolute_percentage_error, mean_squared_error, r2_score

# %%
r2_score(Y_test,Y_pred)
# Out:
# 0.8440738618036301

# %%
mse=mean_squared_error(Y_test,Y_pred)

# %%
np.sqrt(mse)
# Out:
# 30278179.789049555

# %%
mae= mean_absolute_error(Y_test,Y_pred)
mae
# Out:
# 16313192.961787648

# %%
sns.relplot(X_test[:,0],Y_test, color= "Red" )
sns.regplot(X_test[:,0],Y_pred, ci=False)
plt.show()

# %% [markdown]
# # Our model is given perfect prediction but still lets check model is there any change after applying regularisation.

# %%
from sklearn.linear_model import Lasso

# %%
lasso=Lasso()

# %%
lasso.fit(X_train,Y_train)
# Out:
# Lasso()

# %%
y_pred_lasso=lasso.predict(X_test)

# %%
r2_score(Y_test,y_pred_lasso)
# Out:
# 0.8440742571106032

# %% [markdown]
# # Model Discription

# %%
from statsmodels.regression.linear_model import OLS
import statsmodels.api as sm

# %%
ols=sm.OLS(y,X)

# %%
model= ols.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:         Total_turnover   R-squared (uncentered):                   0.857
# Model:                            OLS   Adj. R-squared (uncentered):              0.857
# Method:                 Least Squares   F-statistic:                              2544.
# Date:                Thu, 01 Sep 2022   Prob (F-statistic):                        0.00
# Time:                        19:57:52   Log-Likelihood:                         -48102.
# No. Observations:                2553   AIC:                                  9.622e+04
# Df Residuals:                    2547   BIC:                                  9.625e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                                 coef    std err          t      P>|t|      [0.025      0.975]
# ...
